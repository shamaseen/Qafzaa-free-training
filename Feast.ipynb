# %% [markdown]
# # Comprehensive Feast Feature Store Tutorial
#
# This notebook demonstrates how to use Feast to create and manage a feature store for machine learning. We'll use a ride-sharing example to show how to handle driver and customer features.
#
# ## What is Feast?
# Feast is an open-source feature store that helps organizations manage and serve machine learning features to production models. It provides:
# - Consistent feature definitions
# - Point-in-time correct feature retrieval
# - Feature sharing and reuse across projects
# - Online and offline feature access

# %%
# Install required packages
# !pip install feast pandas sqlite_vec
# Out:
# Requirement already satisfied: feast in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (0.42.0)
# Requirement already satisfied: pandas in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: sqlite_vec in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (0.1.6)
# Requirement already satisfied: pygments<3,>=2.12.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (2.17.2)
# Requirement already satisfied: uvicorn-worker in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.3.0)
# Requirement already satisfied: uvicorn[standard]<1,>=0.14.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.34.0)
# Requirement already satisfied: tabulate<1,>=0.8.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.9.0)
# Requirement already satisfied: bigtree>=0.19.2 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.23.0)
# Requirement already satisfied: SQLAlchemy[mypy]>1 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (1.4.54)
# Requirement already satisfied: tqdm<5,>=4 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (4.66.1)
# Requirement already satisfied: psutil in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (5.9.8)
# Requirement already satisfied: fastapi>=0.68.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.115.6)
# Requirement already satisfied: requests in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (2.32.3)
# Requirement already satisfied: toml<1,>=0.10.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.10.2)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (8.1.7)
# Requirement already satisfied: gunicorn in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (21.2.0)
# Requirement already satisfied: dask[dataframe]>=2024.2.1 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (2025.1.0)
# Requirement already satisfied: typeguard>=4.0.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (4.4.1)
# Requirement already satisfied: tenacity<9,>=7 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (8.2.3)
# Requirement already satisfied: Jinja2<4,>=2 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (3.1.2)
# Requirement already satisfied: protobuf<5.0.0,>=4.24.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (4.25.5)
# Requirement already satisfied: pyarrow<18.1.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (14.0.1)
# Requirement already satisfied: pydantic>=2.0.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (2.10.5)
# Requirement already satisfied: PyYAML<7,>=5.4.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (6.0.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.4.6)
# Requirement already satisfied: jsonschema in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (4.20.0)
# Requirement already satisfied: mmh3 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (5.0.1)
# Requirement already satisfied: numpy<2,>=1.22 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (1.24.1)
# Requirement already satisfied: pyjwt in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (2.8.0)
# Requirement already satisfied: dill~=0.3.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.3.8)
# Requirement already satisfied: prometheus_client in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from feast) (0.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from dask[dataframe]>=2024.2.1->feast) (3.1.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from dask[dataframe]>=2024.2.1->feast) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from dask[dataframe]>=2024.2.1->feast) (23.2)
# Requirement already satisfied: partd>=1.4.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from dask[dataframe]>=2024.2.1->feast) (1.4.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from dask[dataframe]>=2024.2.1->feast) (2023.12.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from dask[dataframe]>=2024.2.1->feast) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (4.12.2)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (0.41.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from Jinja2<4,>=2->feast) (2.1.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from pydantic>=2.0.0->feast) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from pydantic>=2.0.0->feast) (2.27.2)
# Requirement already satisfied: six>=1.5 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from SQLAlchemy[mypy]>1->feast) (3.1.1)
# Requirement already satisfied: mypy>=0.910 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from SQLAlchemy[mypy]>1->feast) (1.14.1)
# Requirement already satisfied: sqlalchemy2-stubs in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from SQLAlchemy[mypy]>1->feast) (0.0.2a38)
# Requirement already satisfied: h11>=0.8 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.14.0)
# Requirement already satisfied: websockets>=10.4 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (14.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (1.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from jsonschema->feast) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from jsonschema->feast) (0.31.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from jsonschema->feast) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from jsonschema->feast) (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from requests->feast) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from requests->feast) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from requests->feast) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from requests->feast) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from importlib_metadata>=4.13.0->dask[dataframe]>=2024.2.1->feast) (3.17.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from mypy>=0.910->SQLAlchemy[mypy]>1->feast) (2.0.1)
# Requirement already satisfied: mypy_extensions>=1.0.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from mypy>=0.910->SQLAlchemy[mypy]>1->feast) (1.0.0)
# Requirement already satisfied: locket in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from partd>=1.4.0->dask[dataframe]>=2024.2.1->feast) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from starlette<0.42.0,>=0.40.0->fastapi>=0.68.0->feast) (4.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.68.0->feast) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.68.0->feast) (1.2.0)

# %%
import feast
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta
from feast import FeatureStore, Entity, FeatureView, ValueType, FeatureService
from feast import FileSource
from feast.on_demand_feature_view import on_demand_feature_view
from feast.field import Field
from feast.types import Float32, Int64, String
# Out:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Step 1: Set Up a Feature Repository
#
# First, we'll create a new Feast feature repository and set up our project structure.

# %%
# Initialize a new feature repository
# !feast init ride_sharing_features
# Out:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#
# Creating a new Feast repository in /home/shamaseen/Desktop/Shai/qafza/free_Training/ride_sharing_features.

# %%
# Navigate to the feature repository directory
# %cd ride_sharing_features/feature_repo
# Out:
# /home/shamaseen/Desktop/Shai/qafza/free_Training/ride_sharing_features/feature_repo

# %% [markdown]
# # Step 2: Create Sample Datasets
#
# Let's create multiple realistic datasets for our ride-sharing example:

# %%
# Load and prepare the diabetes dataset
data = pd.read_csv('https://raw.githubusercontent.com/TripathiAshutosh/feast/main/Feast%20Live%20Demo/diabetes.csv')
data['event_timestamp'] = datetime.now()  # Add timestamp column
data['patient_id'] = range(1, len(data) + 1)  # Add patient ID column

# %%
# Save the data locally
os.makedirs("./data", exist_ok=True)
data.to_parquet("./data/diabetes_data.parquet")

# %% [markdown]
# # Step 3: Define Data Sources and Entities
#
# Now we'll define our data sources and entities for both drivers and customers.

# %%
# Define the source of our feature data
# FileSource tells Feast where to find the feature data and which column contains the timestamp
diabetes_source = FileSource(
    path="data/diabetes_data.parquet",
    event_timestamp_column="event_timestamp",  # Column used for point-in-time joins
)

# Define the patient entity
# Entities are the primary keys used to join and retrieve features
patient = Entity(
    name="patient",
    value_type=ValueType.INT64,  # Data type of the entity
    description="Patient ID",    # Description for documentation
    join_keys=["patient_id"]    # Column(s) used to join features
)

# %% [markdown]
# # Step 4: Create Feature Views
#
# Let's create feature views for both driver and customer statistics, plus an on-demand feature view for derived features.

# %%
# Define the main feature view for diabetes statistics
# Feature views are groups of features that are stored and retrieved together
diabetes_stats_fv = FeatureView(
    name="diabetes_stats",
    entities=[patient],  # Link to the patient entity
    ttl=timedelta(days=365),  # Time-to-live for features (how long they're considered valid)
    schema=[
        # Define each feature's name and data type
        Field(name="Pregnancies", dtype=Int64),
        Field(name="Glucose", dtype=Float32),
        Field(name="BloodPressure", dtype=Float32),
        Field(name="SkinThickness", dtype=Float32),
        Field(name="Insulin", dtype=Float32),
        Field(name="BMI", dtype=Float32),
        Field(name="DiabetesPedigreeFunction", dtype=Float32),
        Field(name="Age", dtype=Int64),
        Field(name="Outcome", dtype=Int64)
    ],
    source=diabetes_source,
    online=True,  # Enable online serving
    description="Diabetes patient statistics and outcomes"
)

# %%
# Define an on-demand feature view for diabetes risk scoring
@on_demand_feature_view(
    sources=[diabetes_stats_fv],
    schema=[
        Field(name="diabetes_risk_score", dtype=Float32),
        Field(name="high_risk", dtype=Int64)
    ]
)

def diabetes_risk_scoring_view(inputs: pd.DataFrame) -> pd.DataFrame:
    """
    Calculate diabetes risk score and risk flag based on patient features.
    
    Args:
        inputs (pd.DataFrame): Input features from diabetes_stats_fv
    
    Returns:
        pd.DataFrame: Calculated risk scores and flags
    """
    df = pd.DataFrame()
    
    # Calculate weighted risk score based on medical features
    df['diabetes_risk_score'] = (
        (inputs['Glucose'] / 200) * 0.3 +      # Glucose level contribution
        (inputs['BMI'] / 50) * 0.2 +           # BMI contribution
        (inputs['Age'] / 100) * 0.15 +         # Age contribution
        (inputs['DiabetesPedigreeFunction']) * 0.15 +  # Genetic contribution
        (inputs['BloodPressure'] / 200) * 0.1 +        # Blood pressure contribution
        (inputs['Insulin'] / 846) * 0.1        # Insulin level contribution
    ).round(3)
    
    # Flag high-risk patients (score > 0.6)
    df['high_risk'] = (df['diabetes_risk_score'] > 0.6).astype(int)
    
    # Ensure correct data types
    df['diabetes_risk_score'] = df['diabetes_risk_score'].astype('float32')
    df['high_risk'] = df['high_risk'].astype('int64')
    
    return df

# %% [markdown]
# # Step 5: Create Feature Services
#
# Feature services help organize features into logical groups for different use cases.

# %%
# Define a feature service for diabetes monitoring
# Feature services group features for specific use cases
diabetes_monitoring_fs = FeatureService(
    name="diabetes_monitoring",
    features=[
        diabetes_stats_fv,
        diabetes_risk_scoring_view
    ],
    description="Features for monitoring diabetes risk and patient statistics"
)

# %% [markdown]
# # Step 6: Apply the Feature Repository

# %%
# Initialize and apply the feature store configuration
store = FeatureStore(repo_path=".")
store.apply([
    patient,
    diabetes_stats_fv,
    diabetes_risk_scoring_view,
    diabetes_monitoring_fs
])

print("Feature repository applied successfully!")
# Out:
# Feature repository applied successfully!
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/feast/feature_store.py:575: RuntimeWarning: On demand feature view is an experimental feature. This API is stable, but the functionality does not scale well for offline retrieval
#   warnings.warn(

# %% [markdown]
# # Step 7: Feature Retrieval Examples
#
# Let's demonstrate various ways to retrieve features from our feature store.

# %%
# Example: Retrieve features for training
def get_training_features(patient_ids=None):
    """
    Retrieve historical features for model training.
    
    Args:
        patient_ids: List of patient IDs to retrieve features for
                    If None, defaults to first 10 patients
    
    Returns:
        pd.DataFrame: Training dataset with features and timestamps
    """
    if patient_ids is None:
        patient_ids = range(1, 11)
        
    # Create entity dataframe with timestamps
    training_entity_df = pd.DataFrame({
        "patient_id": patient_ids,
        "event_timestamp": [datetime.now() for _ in patient_ids]
    })
    
    training_df = store.get_historical_features(
        entity_df=training_entity_df,
        features=[
            "diabetes_stats:Glucose",
            "diabetes_stats:BMI",
            "diabetes_stats:Age",
            "diabetes_stats:DiabetesPedigreeFunction",  
            "diabetes_stats:BloodPressure",
            "diabetes_stats:Insulin",   
            "diabetes_stats:Outcome",
            "diabetes_risk_scoring_view:diabetes_risk_score",
            "diabetes_risk_scoring_view:high_risk"
        ]
    ).to_df()
    
    return training_df

# %%
# Get training features for first 5 patients
print("\nTraining Features Sample:")
get_training_features(range(1, 6))
# Out:
# Training Features Sample:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pyarrow/pandas_compat.py:722: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pyarrow/pandas_compat.py:722: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
#    patient_id                  event_timestamp  Glucose   BMI  Age  \
# 0           1 2025-01-22 23:10:59.041165+00:00      148  33.6   50
# 1           2 2025-01-22 23:10:59.041167+00:00       85  26.6   31
# 2           3 2025-01-22 23:10:59.041167+00:00      183  23.3   32
# 3           4 2025-01-22 23:10:59.041167+00:00       89  28.1   21
# 4           5 2025-01-22 23:10:59.041168+00:00      137  43.1   33
#
#    DiabetesPedigreeFunction  BloodPressure  Insulin  Outcome  \
# 0                     0.627             72        0        1
# 1                     0.351             66        0        0
# 2                     0.672             64        0        1
# 3                     0.167             66       94        0
# 4                     2.288             40      168        1
#
#    diabetes_risk_score  high_risk
# 0                0.561          0
# 1                0.366          0
# 2                0.548          0
# 3                0.347          0
# 4                0.810          1

# %%
## (Loading the features to online store)
## There are two ways you can use to load features to your online store

## - materialize
## materialize loads the latest features between two dates.

## feast materialize 2020–01–01T00:00:00 2022–01–01T00:00:00

## - materialize-incremental
## materialize-incremental loads features up to the provided end date:

## feast materialize-incremental 2022–01–01T00:00:00

def materialize_features():
    """
    Materialize features to the online store.
    
    This function is crucial for online serving as it:
    1. Takes the latest feature values from the offline store
    2. Transforms them into a format suitable for fast retrieval
    3. Loads them into the online store
    4. Ensures features are available for real-time serving
    
    Without materialization, online feature retrieval will return None values.
    """

    # store.materialize(start_date=datetime.utcnow() - timedelta(days=530), end_date=datetime.utcnow() - timedelta(days=10))
    
    store.materialize_incremental(end_date=datetime.now())

# %%
# Example: Get online features for real-time prediction
def get_online_features(patient_id):
    """
    Retrieve real-time features for a single patient.
    
    This function is used for making predictions on new or current patients.
    It requires features to be materialized in the online store.
    
    Args:
        patient_id: ID of the patient to retrieve features for
    
    Returns:
        dict: Dictionary containing the patient's features
    """
    try:
        # Ensure features are materialized
        materialize_features()
        
        # Retrieve online features
        online_features = store.get_online_features(
            entity_rows=[{"patient_id": patient_id}],
            features=[
                "diabetes_stats:Glucose",
                "diabetes_stats:BMI",
                "diabetes_stats:Age",
                "diabetes_stats:DiabetesPedigreeFunction",
                "diabetes_stats:BloodPressure",
                "diabetes_stats:Insulin",
                "diabetes_stats:Outcome",
                "diabetes_risk_scoring_view:diabetes_risk_score",
                "diabetes_risk_scoring_view:high_risk"
            ]
        ).to_dict()
        
        return online_features
    except Exception as e:
        print(f"Error getting online features: {e}")
        return None

# %%
# Get online features for patient ID 1
print("\nOnline Features Sample:")
print(get_online_features(patient_id=[1]))
# Out:
# Online Features Sample:
# Materializing 1 feature views to 2025-01-22 23:10:59+03:00 into the sqlite online store.
#
# diabetes_stats from 2024-01-23 23:10:59+03:00 to 2025-01-22 23:10:59+03:00:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
#   0%|                                                                       | 0/768 [00:00<?, ?it/s]
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████| 768/768 [00:00<00:00, 10919.37it/s]
# Error getting online features: int() argument must be a string, a bytes-like object or a real number, not 'list'
# None

# %% [markdown]
# # Step 8: Clean Up and Best Practices

# %%
def check_feature_store_health():
    """
    Check the health and status of the feature store.
    
    This function provides visibility into:
    1. Available feature views
    2. Configured feature services
    3. Registered entities
    4. Data sources
    
    Useful for debugging and monitoring the feature store setup.
    """
    health_status = {
        "feature_views": store.list_feature_views(),
        "feature_services": store.list_feature_services(),
        "entities": store.list_entities(),
        "data_sources": [source.path for view in store.list_feature_views() 
                        for source in [view.batch_source]]
    }
    
    print("Feature Store Health Check:")
    for component, items in health_status.items():
        print(f"\n{component.title()}:")
        for item in items:
            print(f"  - {item}")

# %%
check_feature_store_health()
# Out:
# Feature Store Health Check:
#
# Feature_Views:
#   - {
#   "spec": {
#     "name": "diabetes_stats",
#     "entities": [
#       "patient"
#     ],
#     "features": [
#       {
#         "name": "Pregnancies",
#         "valueType": "INT64"
#       },
#       {
#         "name": "Glucose",
#         "valueType": "FLOAT"
#       },
#       {
#         "name": "BloodPressure",
#         "valueType": "FLOAT"
#       },
#       {
#         "name": "SkinThickness",
#         "valueType": "FLOAT"
#       },
#       {
#         "name": "Insulin",
#         "valueType": "FLOAT"
#       },
#       {
#         "name": "BMI",
#         "valueType": "FLOAT"
#       },
#       {
#         "name": "DiabetesPedigreeFunction",
#         "valueType": "FLOAT"
#       },
#       {
#         "name": "Age",
#         "valueType": "INT64"
#       },
#       {
#         "name": "Outcome",
#         "valueType": "INT64"
#       }
#     ],
#     "ttl": "31536000s",
#     "batchSource": {
#       "type": "BATCH_FILE",
#       "timestampField": "event_timestamp",
#       "fileOptions": {
#         "uri": "data/diabetes_data.parquet"
#       },
#       "dataSourceClassType": "feast.infra.offline_stores.file_source.FileSource",
#       "name": "data/diabetes_data.parquet"
#     },
#     "online": true,
#     "description": "Diabetes patient statistics and outcomes",
#     "entityColumns": [
#       {
#         "name": "patient_id",
#         "valueType": "INT64"
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2025-01-22T20:10:59.005567Z",
#     "lastUpdatedTimestamp": "2025-01-22T20:10:59.317975Z",
#     "materializationIntervals": [
#       {
#         "startTime": "2024-01-23T20:10:59.196607Z",
#         "endTime": "2025-01-22T23:10:59.194679Z"
#       }
#     ]
#   }
# }
#
# Feature_Services:
#   - {
#   "spec": {
#     "name": "diabetes_monitoring",
#     "features": [
#       {
#         "featureViewName": "diabetes_stats",
#         "featureColumns": [
#           {
#             "name": "Pregnancies",
#             "valueType": "INT64"
#           },
#           {
#             "name": "Glucose",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "BloodPressure",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "SkinThickness",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "Insulin",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "BMI",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "DiabetesPedigreeFunction",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "Age",
#             "valueType": "INT64"
#           },
#           {
#             "name": "Outcome",
#             "valueType": "INT64"
#           }
#         ],
#         "batchSource": {
#           "type": "BATCH_FILE",
#           "timestampField": "event_timestamp",
#           "fileOptions": {
#             "uri": "data/diabetes_data.parquet"
#           },
#           "name": "data/diabetes_data.parquet"
#         }
#       },
#       {
#         "featureViewName": "diabetes_risk_scoring_view",
#         "featureColumns": [
#           {
#             "name": "diabetes_risk_score",
#             "valueType": "FLOAT"
#           },
#           {
#             "name": "high_risk",
#             "valueType": "INT64"
#           }
#         ]
#       }
#     ],
#     "description": "Features for monitoring diabetes risk and patient statistics"
#   },
#   "meta": {
#     "createdTimestamp": "2025-01-22T20:10:59.007168Z",
#     "lastUpdatedTimestamp": "2025-01-22T20:10:59.007168Z"
#   }
# }
#
# Entities:
#   - {
#   "spec": {
#     "name": "patient",
#     "valueType": "INT64",
#     "description": "Patient ID",
#     "joinKey": "patient_id"
#   },
#   "meta": {
#     "createdTimestamp": "2025-01-22T20:10:59.006974Z",
#     "lastUpdatedTimestamp": "2025-01-22T20:10:59.006974Z"
#   }
# }
#
# Data_Sources:
#   - data/diabetes_data.parquet

# %% [markdown]
# # Step 9 : Traning

# %%
from feast import FeatureStore
from feast.infra.offline_stores.file_source import SavedDatasetFileStorage

store = FeatureStore(repo_path='.')

entity_df = pd.read_parquet(path = 'data/diabetes_data.parquet')[['patient_id','event_timestamp']]

training_data = store.get_historical_features(
entity_df = entity_df,
    features = [
        "diabetes_stats:Pregnancies",
        "diabetes_stats:Glucose",
        "diabetes_stats:BloodPressure",
        "diabetes_stats:SkinThickness",
        "diabetes_stats:Insulin",
        "diabetes_stats:BMI",
        "diabetes_stats:DiabetesPedigreeFunction",
        "diabetes_stats:Age",
        "diabetes_stats:Outcome",
               ]
)

dataset = store.create_saved_dataset(
from_=training_data,
    name = "diabetes_dataset",
    storage = SavedDatasetFileStorage('data/diabetes_dataset1.parquet')
)
# Out:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/feast/feature_store.py:1201: RuntimeWarning: Saving dataset is an experimental feature. This API is unstable and it could and most probably will be changed in the future. We do not guarantee that future changes will maintain backward compatibility.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(

# %%
pd.read_parquet("data/diabetes_dataset1.parquet")
# Out:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pyarrow/pandas_compat.py:722: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
#      patient_id                  event_timestamp  Pregnancies  Glucose  \
# 0             1 2025-01-22 23:10:58.353939+00:00            6      148
# 1           507 2025-01-22 23:10:58.353939+00:00            0      180
# 2           508 2025-01-22 23:10:58.353939+00:00            1      130
# 3           509 2025-01-22 23:10:58.353939+00:00            2       84
# 4           510 2025-01-22 23:10:58.353939+00:00            8      120
# ..          ...                              ...          ...      ...
# 763         260 2025-01-22 23:10:58.353939+00:00           11      155
# 764         261 2025-01-22 23:10:58.353939+00:00            3      191
# 765         262 2025-01-22 23:10:58.353939+00:00            3      141
# 766         767 2025-01-22 23:10:58.353939+00:00            1      126
# 767         768 2025-01-22 23:10:58.353939+00:00            1       93
#
#      BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  \
# 0               72             35        0  33.6                     0.627
# 1               90             26       90  36.5                     0.314
# 2               60             23      170  28.6                     0.692
# 3               50             23       76  30.4                     0.968
# 4               78              0        0  25.0                     0.409
# ..             ...            ...      ...   ...                       ...
# 763             76             28      150  33.3                     1.353
# 764             68             15      130  30.9                     0.299
# 765              0              0        0  30.0                     0.761
# 766             60              0        0  30.1                     0.349
# 767             70             31        0  30.4                     0.315
#
#      Age  Outcome
# 0     50        1
# 1     35        1
# 2     21        0
# 3     21        0
# 4     64        0
# ..   ...      ...
# 763   51        1
# 764   34        0
# 765   27        1
# 766   47        1
# 767   23        0
#
# [768 rows x 11 columns]

# %%
# Importing dependencies
from feast import FeatureStore
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from joblib import dump

# Getting our FeatureStore
store = FeatureStore(repo_path=".")

# Retrieving the saved dataset and converting it to a DataFrame
training_df = training_data.to_df() #store.get_saved_dataset(name="diabetes_dataset").to_df()

# Separating the features and labels
y = training_df['Outcome']
X = training_df.drop(
    labels=['Outcome', 'event_timestamp', "patient_id"], 
    axis=1)

# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    stratify=y)

# Creating and training LogisticRegression
reg = LogisticRegression(max_iter = 200)
reg.fit(X=X_train[sorted(X_train)], y=y_train)

# Saving the model
dump(value=reg, filename="model.joblib")
# Out:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pyarrow/pandas_compat.py:722: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# ['model.joblib']

# %%
# Importing dependencies
from feast import FeatureStore
from datetime import datetime, timedelta

# Getting our FeatureStore
store = FeatureStore(repo_path=".")

#store.materialize_incremental(end_date = datetime.now())

store.materialize(start_date=datetime.utcnow() - timedelta(days=530), end_date=datetime.utcnow() - timedelta(days=10))
# Out:
# Materializing 1 feature views from 2023-08-11 20:18:48+03:00 to 2025-01-12 20:18:48+03:00 into the sqlite online store.
#
# diabetes_stats:
# /home/shamaseen/anaconda3/envs/phone/lib/python3.10/site-packages/pandas/core/frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# 0it [00:00, ?it/s]

# %%
# Importing dependencies
from feast import FeatureStore
import pandas as pd
from joblib import load

# Getting our FeatureStore
store = FeatureStore(repo_path=".")

# Defining our features names
feast_features = [
        "diabetes_stats:Pregnancies",
        "diabetes_stats:Glucose",
        "diabetes_stats:BloodPressure",
        "diabetes_stats:SkinThickness",
        "diabetes_stats:Insulin",
        "diabetes_stats:BMI",
        "diabetes_stats:DiabetesPedigreeFunction",
        "diabetes_stats:Age",
    ]

# Getting the latest features
features = store.get_online_features(
    features=feast_features,    
    entity_rows=[{"patient_id": 767}, {"patient_id": 766}]
).to_dict()

# Converting the features to a DataFrame
features_df = pd.DataFrame.from_dict(data=features)

# %%
features_df.head()
# Out:
#    patient_id  SkinThickness  Pregnancies  BloodPressure  Glucose  Age  \
# 0         767            0.0            1           60.0    126.0   47
# 1         766           23.0            5           72.0    121.0   30
#
#    Insulin        BMI  DiabetesPedigreeFunction
# 0      0.0  30.100000                     0.349
# 1    112.0  26.200001                     0.245

# %% [markdown]
# # Step 10: Call the predict function and see the output

# %%
features_df.drop("patient_id", axis=1)
# Out:
#    SkinThickness  Pregnancies  BloodPressure  Glucose  Age  Insulin  \
# 0            0.0            1           60.0    126.0   47      0.0
# 1           23.0            5           72.0    121.0   30    112.0
#
#          BMI  DiabetesPedigreeFunction
# 0  30.100000                     0.349
# 1  26.200001                     0.245

# %%
# Loading our model and doing inference
reg = load("model.joblib")
predictions = reg.predict(features_df[sorted(features_df.drop("patient_id", axis=1))])
print(predictions)
prediction_probabilities = reg.predict_proba(features_df[sorted(features_df.drop("patient_id", axis=1))])
print(prediction_probabilities)
# Out:
# [0 0]
# [[0.7426289  0.2573711 ]
#  [0.81199663 0.18800337]]
